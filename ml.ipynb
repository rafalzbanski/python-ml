# %% [markdown]
# # Project Mashine Learning
# ## GOAL -> Predict whether cancer is malignant or not.
# ### Analysis performed on the breast cancer dataset. <br>The dataset contains information about whether it is a malicious case or not.

# %% [markdown]
# ## Part 1 <BR> ....................................................................................

# %%
# necessary libraries
# ---------------------
# !pip3 install matplotlib
# !pip3 install scikit-learn
# !pip3 install pandas
# !pip3 install numpy
# !pip3 install openpyxl
# !pip3 install jinja2

# %%
import matplotlib.pyplot as plt
# from sklearn.datasets import load_breast_cancer
import pandas as pd

df = pd.read_csv(r"/Users/zbanski/Desktop/projects/python_projects/ml/model/data.csv")
df.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst perimeter  worst area  worst smoothness  \
# ...

# %%
len(df)
# Out:
# 569

# %%
df['target'].head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: target, dtype: int64

# %%
df['target'].value_counts()
# Out:
# target
# 1    357
# 0    212
# Name: count, dtype: int64

# %% [markdown]
# ## Data visualization <br>------------------------------------------------------------

# %%
from sklearn.datasets import load_breast_cancer

dataset = load_breast_cancer(as_frame=True)

# %%
plt.matshow(dataset['data'].corr())
plt.show()

# %%
import numpy as np

corr = dataset['data'].corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_c0581_row0_col0, #T_c0581_row0_col2, #T_c0581_row1_col1, #T_c0581_row2_col0, #T_c0581_row2_col2, #T_c0581_row3_col3, #T_c0581_row4_col4, #T_c0581_row5_col5, #T_c0581_row6_col6, #T_c0581_row7_col7, #T_c0581_row8_col8, #T_c0581_row9_col9, #T_c0581_row10_col10, #T_c0581_row11_col11, #T_c0581_row12_col12, #T_c0581_row13_col13, #T_c0581_row14_col14, #T_c0581_row15_col15, #T_c0581_row16_col16, #T_c0581_row17_col17, #T_c0581_row18_col18, #T_c0581_row19_col19, #T_c0581_row20_col20, #T_c0581_row21_col21, #T_c0581_row22_col22, #T_c0581_row23_col23, #T_c0581_row24_col24, #T_c0581_row25_col25, #T_c0581_row26_col26, #T_c0581_row27_col27, #T_c0581_row28_col28, #T_c0581_row29_col29 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_c0581_row0_col1, #T_c0581_row4_col2, #T_c0581_row4_col20, #T_c0581_row4_col22, #T_c0581_row24_col22, #T_c0581_row27_col9 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# ...

# %%
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_d235c_row0_col0, #T_d235c_row0_col2, #T_d235c_row1_col1, #T_d235c_row2_col0, #T_d235c_row2_col2, #T_d235c_row3_col3, #T_d235c_row4_col4, #T_d235c_row5_col5, #T_d235c_row6_col6, #T_d235c_row7_col7, #T_d235c_row8_col8, #T_d235c_row9_col9, #T_d235c_row10_col10, #T_d235c_row11_col11, #T_d235c_row12_col12, #T_d235c_row13_col13, #T_d235c_row14_col14, #T_d235c_row15_col15, #T_d235c_row16_col16, #T_d235c_row17_col17, #T_d235c_row18_col18, #T_d235c_row19_col19, #T_d235c_row20_col20, #T_d235c_row21_col21, #T_d235c_row22_col22, #T_d235c_row23_col23, #T_d235c_row24_col24, #T_d235c_row25_col25, #T_d235c_row26_col26, #T_d235c_row27_col27, #T_d235c_row28_col28, #T_d235c_row29_col29 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_d235c_row0_col1, #T_d235c_row4_col2, #T_d235c_row4_col20, #T_d235c_row4_col22, #T_d235c_row24_col22, #T_d235c_row27_col9 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# ...

# %%
corr.style.background_gradient(cmap='coolwarm').set_properties(**{'font-size': '0pt'})
# Out:
# <style type="text/css">
# #T_157fa_row0_col0, #T_157fa_row0_col2, #T_157fa_row1_col1, #T_157fa_row2_col0, #T_157fa_row2_col2, #T_157fa_row3_col3, #T_157fa_row4_col4, #T_157fa_row5_col5, #T_157fa_row6_col6, #T_157fa_row7_col7, #T_157fa_row8_col8, #T_157fa_row9_col9, #T_157fa_row10_col10, #T_157fa_row11_col11, #T_157fa_row12_col12, #T_157fa_row13_col13, #T_157fa_row14_col14, #T_157fa_row15_col15, #T_157fa_row16_col16, #T_157fa_row17_col17, #T_157fa_row18_col18, #T_157fa_row19_col19, #T_157fa_row20_col20, #T_157fa_row21_col21, #T_157fa_row22_col22, #T_157fa_row23_col23, #T_157fa_row24_col24, #T_157fa_row25_col25, #T_157fa_row26_col26, #T_157fa_row27_col27, #T_157fa_row28_col28, #T_157fa_row29_col29 {
#   background-color: #b40426;
#   color: #f1f1f1;
#   font-size: 0pt;
# }
# #T_157fa_row0_col1, #T_157fa_row4_col2, #T_157fa_row4_col20, #T_157fa_row4_col22, #T_157fa_row24_col22, #T_157fa_row27_col9 {
#   background-color: #b7cff9;
#   color: #000000;
#   font-size: 0pt;
# }
# ...

# %%
upper_tri = corr.where(np.triu(np.ones(corr.shape), k=1).astype(bool))

# Find the variables with the highest correlation
max_corr_vars = upper_tri.abs().stack().nlargest(5).reset_index()

# Print the variables with the highest correlation
for index, row in max_corr_vars.iterrows():
    var1, var2 = row['level_0'], row['level_1']
    correlation = corr.loc[var1, var2]
    print(f"Variables '{var1}' and '{var2}' have a correlation of {correlation:.2f}")
# Out:
# Variables 'mean radius' and 'mean perimeter' have a correlation of 1.00
# Variables 'worst radius' and 'worst perimeter' have a correlation of 0.99
# Variables 'mean radius' and 'mean area' have a correlation of 0.99
# Variables 'mean perimeter' and 'mean area' have a correlation of 0.99
# Variables 'worst radius' and 'worst area' have a correlation of 0.98

# %% [markdown]
# ## Data view on df

# %%
# plt.matshow(df.corr())
# plt.show()

# %%
# import numpy as np

# corr = df.corr()
# corr.style.background_gradient(cmap='coolwarm')

# %%
# corr.style.background_gradient(cmap='coolwarm').set_precision(2)

# %%
# corr.style.background_gradient(cmap='coolwarm').set_properties(**{'font-size': '0pt'})

# %%
# upper_tri = corr.where(np.triu(np.ones(corr.shape), k=1).astype(bool))

# # Find the variables with the highest correlation
# max_corr_vars = upper_tri.abs().stack().nlargest(5).reset_index()

# # Print the variables with the highest correlation
# for index, row in max_corr_vars.iterrows():
#     var1, var2 = row['level_0'], row['level_1']
#     correlation = corr.loc[var1, var2]
#     print(f"Variables '{var1}' and '{var2}' have a correlation of {correlation:.2f}")

# %% [markdown]
# ## More calculation

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

model = LogisticRegression()

# X = dataset['data']
X = df[['mean radius', 'mean perimeter', 'worst radius', 'worst perimeter', 'mean area', 'worst area'] ]
y = df['target']

X_train, X_test, y_train, y_test = train_test_split(X, y , test_size=0.33, random_state=42, stratify=y)

model.fit(X_train, y_train)

predictions = model.predict(X_test)

from sklearn.metrics import accuracy_score

accuracy_score(y_test, predictions)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.9468085106382979

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, predictions)

TN, FP, FN, TP = confusion_matrix(y_test, predictions).ravel()

print('True Positive(TP)  = ', TP)
print('False Positive(FP) = ', FP)
print('True Negative(TN)  = ', TN)
print('False Negative(FN) = ', FN)
# Out:
# True Positive(TP)  =  115
# False Positive(FP) =  7
# True Negative(TN)  =  63
# False Negative(FN) =  3

# %%
confusion_matrix(y_test, predictions).ravel()
# Out:
# array([ 63,   7,   3, 115])

# %%
accuracy =  (TP + TN) / (TP + FP + TN + FN)

print('Accuracy of the binary classifier = {:0.3f}'.format(accuracy))
# Out:
# Accuracy of the binary classifier = 0.947

# %%
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score

# %%
precision_score(y_test, predictions)
# Out:
# 0.9426229508196722

# %%
# Określa jaki procent wszystkich prawdziwych obserwacji udało nam się znaleźć.
recall_score(y_test, predictions)
# Out:
# 0.9745762711864406

# %%
f1_score(y_test, predictions)
# Out:
# 0.9583333333333334

# %% [markdown]
# ### Decision tree

# %%
from sklearn.tree import DecisionTreeClassifier, plot_tree

model = DecisionTreeClassifier()

model.fit(X_train, y_train)
y_pred = model.predict(X_test)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.9042553191489362

# %%
model.get_depth()
# Out:
# 8

# %%
model.get_n_leaves()
# Out:
# 26

# %%
model = DecisionTreeClassifier(max_depth=8, criterion='gini')

model.fit(X_train, y_train)
y_pred = model.predict(X_test)

accuracy_score(y_pred, y_test)
# Out:
# 0.9202127659574468

# %%
# %matplotlib inline
fig = plt.figure(figsize=(25, 12))
plot_tree(model, feature_names=model.feature_names_in_, class_names=model.classes_.astype('str'), filled=True);

# %% [markdown]
# ### list of other algorithms

# %%
models = {}

# Logistic Regression
from sklearn.linear_model import LogisticRegression
models['Logistic Regression'] = LogisticRegression()

# Support Vector Machines
from sklearn.svm import LinearSVC
models['Support Vector Machines'] = LinearSVC()

# Decision Trees
from sklearn.tree import DecisionTreeClassifier
models['Decision Trees'] = DecisionTreeClassifier()

# Random Forest
from sklearn.ensemble import RandomForestClassifier
models['Random Forest'] = RandomForestClassifier()

# Naive Bayes
from sklearn.naive_bayes import GaussianNB
models['Naive Bayes'] = GaussianNB()

# K-Nearest Neighbors
from sklearn.neighbors import KNeighborsClassifier
models['K-Nearest Neighbor'] = KNeighborsClassifier()

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score

accuracy, precision, recall = {}, {}, {}

for key in models.keys():
    
    # Fit the classifier
    models[key].fit(X_train, y_train)
    
    # Make predictions
    predictions = models[key].predict(X_test)
    
    # Calculate metrics
    accuracy[key] = accuracy_score(predictions, y_test)
    precision[key] = precision_score(predictions, y_test)
    recall[key] = recall_score(predictions, y_test)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/svm/_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# ...

# %%
import pandas as pd

df_model = pd.DataFrame(index=models.keys(), columns=['Accuracy', 'Precision', 'Recall'])
df_model['Accuracy'] = accuracy.values()
df_model['Precision'] = precision.values()
df_model['Recall'] = recall.values()

df_model
# Out:
#                          Accuracy  Precision    Recall
# Logistic Regression      0.946809   0.974576  0.942623
# Support Vector Machines  0.914894   0.974576  0.898438
# Decision Trees           0.904255   0.898305  0.946429
# Random Forest            0.925532   0.949153  0.933333
# Naive Bayes              0.904255   0.949153  0.903226
# K-Nearest Neighbor       0.914894   0.932203  0.932203

# %%
ax = df_model.plot.barh()
ax.legend(
    ncol=len(models.keys()), 
    bbox_to_anchor=(0, 1), 
    loc='lower left', 
    prop={'size': 14}
)
plt.tight_layout()

# %% [markdown]
# ### Part 2 <br>Linear regrersion<br>.................................................................................................

# %%
df = pd.read_csv(r"/Users/zbanski/Desktop/projects/python_projects/ml/model/Salary_Data.csv", usecols=["YearsExperience", "Salary"]).sample(20)
df
# Out:
#     YearsExperience  Salary
# 19              6.0   93940
# 18              5.9   81363
# 26              9.5  116969
# 29             10.5  121872
# 5               2.9   56642
# 4               2.2   39891
# 23              8.2  113812
# 12              4.0   56957
# 14              4.5   61111
# 17              5.3   83088
# 13              4.1   57081
# 8               3.2   64445
# 21              7.1   98273
# 10              3.9   63218
# 2               1.5   37731
# 11              4.0   55794
# 7               3.2   54445
# 16              5.1   66029
# 3               2.0   43525
# 25              9.0  105582

# %%
import matplotlib.pyplot as plt
import numpy as np 
fig, ax = plt.subplots(figsize=(10, 24), nrows=2)

# ---
ax[0].scatter(df["YearsExperience"], df["Salary"], label='Rzeczywiste dane')
ax[0].set_xlabel("Experience [Years]", fontsize=15)
ax[0].set_ylabel("Salary [PLN]", fontsize=15)
ax[0].set_title("Experience and earnings of selected people", fontsize=18)

# # ---
# ax[1].scatter(df["YearsExperience"], df["Salary"], label='Rzeczywiste dane')
# a, b = np.polyfit(df["YearsExperience"], df["Salary"], 1)
# ax[1].plot(df["YearsExperience"], a*df["Salary"]+b, 'r', label='Aproksymacja y=a*x+b')
# ax[1].set_title(f"Dopasowanie linii prostej do danych: $y$={round(a, 1)}$x${round(b, 1)}", fontsize=18)
# ax[1].set_xlabel("Doświadczenie [LATA]", fontsize=15)
# ax[1].set_ylabel("Zarobki [PLN]", fontsize=15)
# ax[1].legend()


# fig.subplots_adjust(hspace=0.25)
# Out:
# Text(0.5, 1.0, 'Experience and earnings of selected people')

# %%
import matplotlib.pyplot as plt


xpoints = df["YearsExperience"]
ypoints = df["Salary"]

plt.plot(xpoints, ypoints, 'o')
plt.xlabel("Experience [Years]", fontsize=15)
plt.ylabel("Salary [PLN]", fontsize=15)
plt.title("Summary of earnings and experience of selected people", fontsize=18)
plt.show()

# %% [markdown]
# ### Homoscedasticity
